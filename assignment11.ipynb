# %%
number = input("Enter a positive number: ") 

while not number.isdigit() or int(number) <= 0 or number.find(".") != -1 :
    number = input("Enter a valid value: ")
    
sayı = int(number)
boyut = len(number)
total = 0

if sayı > 0 :
    
    for i in range(boyut):
        total += int(number[i])**boyut
    
    if total == sayı :
        print(number + " is an Armstrong number")
        
    else:
        print(number + " is not an Armstrong number")
# Out:
# Enter a positive number: 54.48
# Enter a valid value: -69
# Enter a valid value: 9474
# 9474 is an Armstrong number
